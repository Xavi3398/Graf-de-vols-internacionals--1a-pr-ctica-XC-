# %% [markdown]
# # Pràctica 1

# %%
import numpy as np
import pandas as pd
import random

import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sn

import igraph

from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2
import pycountry

# %% [markdown]
# ## Preparación del dataset

# %% [markdown]
# ### Importación de CSVs

# %%
airports = pd.read_csv('csv/airports.csv', sep=',', header=0, na_values='\\N', true_values=['Y'], false_values=['"N"'], quotechar='"', encoding="utf-8")
airports
# Out:
#          Id                                         Name          City  \
# 0         1                               Goroka Airport        Goroka
# 1         2                               Madang Airport        Madang
# 2         3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3         4                               Nadzab Airport        Nadzab
# 4         5  Port Moresby Jacksons International Airport  Port Moresby
# ...     ...                                          ...           ...
# 7693  14106                          Rogachyovo Air Base        Belaya
# 7694  14107                        Ulan-Ude East Airport      Ulan Ude
# 7695  14108                         Krechevitsy Air Base      Novgorod
# 7696  14109                  Desierto de Atacama Airport       Copiapo
# 7697  14110                           Melitopol Air Base     Melitopol
#
#                Country IATA  ICAO   Latitude   Longitude  Altitude  Timezone  \
# 0     Papua New Guinea  GKA  AYGA  -6.081690  145.391998      5282      10.0
# 1     Papua New Guinea  MAG  AYMD  -5.207080  145.789001        20      10.0
# 2     Papua New Guinea  HGU  AYMH  -5.826790  144.296005      5388      10.0
# 3     Papua New Guinea  LAE  AYNZ  -6.569803  146.725977       239      10.0
# 4     Papua New Guinea  POM  AYPY  -9.443380  147.220001       146      10.0
# ...                ...  ...   ...        ...         ...       ...       ...
# 7693            Russia  NaN  ULDA  71.616699   52.478298       272       NaN
# 7694            Russia  NaN  XIUW  51.849998  107.737999      1670       NaN
# 7695            Russia  NaN  ULLK  58.625000   31.385000        85       NaN
# 7696             Chile  CPO  SCAT -27.261200  -70.779198       670       NaN
# 7697           Ukraine  NaN  UKDM  46.880001   35.305000         0       NaN
#
#       DST Tz database time zone     Type       Source
# 0       U  Pacific/Port_Moresby  airport  OurAirports
# 1       U  Pacific/Port_Moresby  airport  OurAirports
# 2       U  Pacific/Port_Moresby  airport  OurAirports
# 3       U  Pacific/Port_Moresby  airport  OurAirports
# 4       U  Pacific/Port_Moresby  airport  OurAirports
# ...   ...                   ...      ...          ...
# 7693  NaN                   NaN  airport  OurAirports
# 7694  NaN                   NaN  airport  OurAirports
# 7695  NaN                   NaN  airport  OurAirports
# 7696  NaN                   NaN  airport  OurAirports
# 7697  NaN                   NaN  airport  OurAirports
#
# [7698 rows x 14 columns]

# %%
airlines = pd.read_csv('csv/airlines.csv', sep=',',header=0, na_values='\\N', true_values=['Y'], false_values=['N'], quotechar='"', encoding="utf-8")
airlines.Active = airlines.Active.transform(lambda x: True if x == 'Y' else False)
airlines
# Out:
#          Id                                          Name              Alias  \
# 0        -1                                       Unknown                NaN
# 1         1                                Private flight                NaN
# 2         2                                   135 Airways                NaN
# 3         3                                 1Time Airline                NaN
# 4         4  2 Sqn No 1 Elementary Flying Training School                NaN
# ...     ...                                           ...                ...
# 6157  21248                                   GX Airlines                NaN
# 6158  21251                        Lynx Aviation (L3/SSX)                NaN
# 6159  21268                               Jetgo Australia                NaN
# 6160  21270                                  Air Carnival                NaN
# 6161  21317                                 Svyaz Rossiya  Russian Commuter
#
#      IATA ICAO         Callsign         Country  Active
# 0       -  NaN              NaN             NaN    True
# 1       -  NaN              NaN             NaN    True
# 2     NaN  GNL          GENERAL   United States   False
# 3      1T  RNX          NEXTIME    South Africa    True
# 4     NaN  WYT              NaN  United Kingdom   False
# ...   ...  ...              ...             ...     ...
# 6157  NaN  CBG            SPRAY           China    True
# 6158  NaN  SSX           Shasta   United States   False
# 6159   JG  NaN              NaN       Australia    True
# 6160   2S  NaN              NaN           India    True
# 6161   7R  SJM  RussianConnecty          Russia    True
#
# [6162 rows x 8 columns]

# %%
routes = pd.read_csv('csv/routes.csv', sep=',', header=0, na_values='\\N', true_values=['Y'], false_values=['"N"'], quotechar='"', encoding="utf-8")
routes = routes.fillna(-1)
routes = routes[routes.Airline_ID != float('nan')]
routes = routes[routes.Src_A_ID != float('nan')]
routes = routes[routes.Dst_A_ID != float('nan')]
routes.Airline_ID = routes.Airline_ID.astype(int)
routes.Src_A_ID = routes.Src_A_ID.astype(int)
routes.Dst_A_ID = routes.Dst_A_ID.astype(int)
routes
# Out:
#       Airline  Airline_ID Src_A  Src_A_ID Dst_A  Dst_A_ID Codeshare  Stops  \
# 0          2B         410   AER      2965   KZN      2990        -1      0
# 1          2B         410   ASF      2966   KZN      2990        -1      0
# 2          2B         410   ASF      2966   MRV      2962        -1      0
# 3          2B         410   CEK      2968   KZN      2990        -1      0
# 4          2B         410   CEK      2968   OVB      4078        -1      0
# ...       ...         ...   ...       ...   ...       ...       ...    ...
# 67658      ZL        4178   WYA      6334   ADL      3341        -1      0
# 67659      ZM       19016   DME      4029   FRU      2912        -1      0
# 67660      ZM       19016   FRU      2912   DME      4029        -1      0
# 67661      ZM       19016   FRU      2912   OSS      2913        -1      0
# 67662      ZM       19016   OSS      2913   FRU      2912        -1      0
#
#       Equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 67658       SF3
# 67659       734
# 67660       734
# 67661       734
# 67662       734
#
# [67663 rows x 9 columns]

# %%
# countries = pd.read_csv('csv/countries.csv', sep=',', header=0, na_values='\\N', true_values=['Y'], false_values=['"N"'], quotechar='"', encoding="latin-1")
# countries

# %% [markdown]
# ### Fusión de tablas

# %%
# Source Airport info
routes_ext = pd.merge(routes, airports, left_on='Src_A_ID',right_on='Id')
routes_ext = routes_ext.rename(columns={"Name": "Src_Name", "Country": "Src_Country"})

# Destination Airport info
routes_ext = pd.merge(routes_ext, airports, left_on='Dst_A_ID', right_on='Id')
routes_ext = routes_ext.rename(columns={"Name": "Dst_Name", "Country": "Dst_Country"})

# Airline info
routes_ext = pd.merge(routes_ext, airlines, left_on='Airline_ID', right_on='Id')
routes_ext = routes_ext.rename(columns={"Name": "Airline_Name", "Country": "Airline_Country"})

routes_ext.columns
# Out:
# Index(['Airline', 'Airline_ID', 'Src_A', 'Src_A_ID', 'Dst_A', 'Dst_A_ID',
#        'Codeshare', 'Stops', 'Equipment', 'Id_x', 'Src_Name', 'City_x',
#        'Src_Country', 'IATA_x', 'ICAO_x', 'Latitude_x', 'Longitude_x',
#        'Altitude_x', 'Timezone_x', 'DST_x', 'Tz database time zone_x',
#        'Type_x', 'Source_x', 'Id_y', 'Dst_Name', 'City_y', 'Dst_Country',
#        'IATA_y', 'ICAO_y', 'Latitude_y', 'Longitude_y', 'Altitude_y',
#        'Timezone_y', 'DST_y', 'Tz database time zone_y', 'Type_y', 'Source_y',
#        'Id', 'Airline_Name', 'Alias', 'IATA', 'ICAO', 'Callsign',
#        'Airline_Country', 'Active'],
#       dtype='object')

# %% [markdown]
# ## Grafo

# %%
def build_graph(dfs, plot=None, verbose=True, seed = 1234, name = 'graf', p_color = 'color_pais', p_label = 'name', rem_can_eua = False):

    g = igraph.Graph()

    for i, row in dfs.iterrows():
        
        if not rem_can_eua or (row.Src_Country != 'Canada' and row.Dst_Country != 'Canada' and row.Src_Country != 'United States' and row.Dst_Country != 'United States'):
        
            if 'name' not in g.vs.attribute_names():
                g.add_vertex(
                    name=str(row.Src_A_ID), 
                    pais=row.Src_Country,
                    continent=dict_pais_continent(row.Src_Country),
                    color_pais = dict_pais_color(row.Src_Country),
                    color_continent = dict_continent_color(dict_pais_continent(row.Src_Country)))
                g.add_vertex(
                    name=str(row.Dst_A_ID), 
                    pais=row.Dst_A_ID,
                    continent=dict_pais_continent(row.Dst_A_ID),
                    color_pais = dict_pais_color(row.Dst_A_ID),
                    color_continent = dict_continent_color(dict_pais_continent(row.Dst_A_ID)))
            else:
                if str(row.Src_A_ID) not in g.vs['name']:
                    g.add_vertex(
                        name=str(row.Src_A_ID), 
                        pais=row.Src_Country,
                        continent=dict_pais_continent(row.Src_Country),
                        color_pais = dict_pais_color(row.Src_Country),
                        color_continent = dict_continent_color(dict_pais_continent(row.Src_Country)))
                if str(row.Dst_A_ID) not in g.vs['name']:
                    g.add_vertex(
                        name=str(row.Dst_A_ID), 
                        pais=row.Dst_A_ID,
                        continent=dict_pais_continent(row.Dst_A_ID),
                        color_pais = dict_pais_color(row.Dst_A_ID),
                        color_continent = dict_continent_color(dict_pais_continent(row.Dst_A_ID)))

            if not g.are_connected(str(row.Src_A_ID), str(row.Dst_A_ID)):
                g.add_edge(str(row.Src_A_ID), str(row.Dst_A_ID), rutas=[i])
            else:
                g.es['rutas'][g.get_eid(str(row.Src_A_ID), str(row.Dst_A_ID))].append(i)

    if verbose:
        print(g.summary())
    
    plot_graph(g, plot = plot, seed = seed, name = name, p_color = p_color, p_label = p_label)
    
    return g

def plot_graph(g, plot = None, seed = 1234, name = 'graf', p_color = 'color_pais', p_label = 'name'):
        
    if plot == 'show':
        
        g.vs['label'] = None
        
        if p_color != None:
            g.vs['color'] = g.vs[p_color]
        else:
            g.vs['color'] = None
        
        igraph.plot(g, bbox=(600, 600), vertex_size=10)
        
    elif plot == 'save':
        
        # etiquetes
        if p_label != None:
            g.vs['label'] = g.vs[p_label]
        else:
            g.vs['label'] = None
        
        # colors
        if p_color != None:
            g.vs['color'] = g.vs[p_color]
        else:
            g.vs['color'] = None
        
        visual_style = {}
        random.seed(seed)

        visual_style["bbox"] = (10000,10000)
        visual_style["margin"] = 20
        visual_style["vertex_size"] = 20
        visual_style["vertex_label_size"] = 8
        visual_style["edge_curved"] = False
        my_layout = g.layout_drl()
        visual_style["layout"] = my_layout
        
        out = igraph.plot(g, **visual_style)
        out.save(name + '.png')
    
# devuelve la información sobre la lista de rutas entre dos aeropuertos
def info_rutas_arista(t_rutas, g, id_arista, columna = None):
    if columna:
        return t_rutas.loc[g.es['rutas'][id_arista]][columna]
    else:
        return t_rutas.loc[g.es['rutas'][id_arista]]

# devuelve la información sobre el aeropuerto de un vértice
def info_aeropuerto_vertice(t_aeropuertos, g, idv):
        
    if isinstance(idv, list):
        if isinstance(idv[0], str):
            return t_aeropuertos.loc[t_aeropuertos['Id'].isin(list(map(int, idv)))]
        else:
            return t_aeropuertos.loc[t_aeropuertos['Id'].isin(list(map(int, np.array(g.vs['name'])[np.isin(np.array(g.vs.indices), np.array(idv))])))]
    else:
        if isinstance(idv, str):
            return t_aeropuertos.loc[t_aeropuertos['Id'] == int(idv)]
        else:
            return t_aeropuertos.loc[t_aeropuertos['Id'] == int(g.vs['name'][idv])]

# %%
# Països diferents
paisos = list(routes_ext['Src_Country'])
paisos.extend(list(routes_ext['Dst_Country']))
paisos = list(set(paisos))

# Color per cada país
colors_pais = ["#"+''.join([random.choice('0123456789ABCDEF') for i in range(6)])for j in range(len(paisos))]
dict_pais_color = dict(zip(paisos, colors_pais))

# Continent per cada país
alpha2 = [country_name_to_country_alpha2(pais) for pais in paisos]

rem = ['TL', 'SX', 'EH']
rep = ['CN', 'US', 'MA']

for i in range(len(rem)):
    ind = alpha2.index(rem[i])
    alpha2[ind] = rep[i]

continents_tots = [country_alpha2_to_continent_code(a2) for a2 in alpha2]
dict_pais_continent = dict(zip(paisos, continents_tots))

# Continents diferents
continents = list(set(continents_tots))
colors_continent = ["#"+''.join([random.choice('0123456789ABCDEF') for i in range(6)])for j in range(len(continents))]
dict_continent_color = dict(zip(continents, colors_continent))

# %% [markdown]
# ### Muestra de 1000 aeropuertos (o todos ellos)

# %%
all_airports = set({})
all_airports.update(routes.Src_A_ID)
all_airports.update(routes.Dst_A_ID)
all_airports = list(all_airports)

r_airports = random.sample(all_airports, len(all_airports))

dfs = routes_ext[routes_ext.Src_A_ID.isin(r_airports)]
dfs = dfs[dfs.Dst_A_ID.isin(r_airports)]

# %% [markdown]
# ### Construcción del grafo

# %%
g = igraph.Graph()

for i, row in dfs.iterrows():
    if 'name' not in g.vs.attribute_names():
        g.add_vertex(name=str(row.Src_A_ID), color=dict_colors[row.Src_Country], label=str(row.Src_A_ID))
        g.add_vertex(name=str(row.Dst_A_ID), color=dict_colors[row.Dst_Country], label=str(row.Dst_A_ID))
    else:
        if str(row.Src_A_ID) not in g.vs['name']:
            g.add_vertex(name=str(row.Src_A_ID), color=dict_colors[row.Src_Country], label=str(row.Src_A_ID))
        if str(row.Dst_A_ID) not in g.vs['name']:
            g.add_vertex(name=str(row.Dst_A_ID), color=dict_colors[row.Dst_Country], label=str(row.Dst_A_ID))
    if not g.are_connected(str(row.Src_A_ID), str(row.Dst_A_ID)):
        g.add_edge(str(row.Src_A_ID), str(row.Dst_A_ID), rutas=[i])
    else:
        g.es['rutas'][g.get_eid(str(row.Src_A_ID), str(row.Dst_A_ID))].append(i)
        
print(g.summary())
# Out:
# IGRAPH UN-- 3214 18859 --
# + attr: color (v), label (v), name (v), rutas (e)

# %%
# igraph.plot(g, bbox=(600, 600), vertex_size=10)
# out = igraph.plot(g, bbox=(600, 600), vertex_size=10)
# out.save('graf.png')

# %%
visual_style = {}
random.seed(1234)

visual_style["bbox"] = (10000,10000)
visual_style["margin"] = 20
visual_style["vertex_size"] = 20
visual_style["vertex_label_size"] = 8
visual_style["edge_curved"] = False
my_layout = g.layout_drl()
visual_style["layout"] = my_layout

# %%
out = igraph.plot(g, **visual_style)
out.save('graf.png')

# %% [markdown]
# ### Cálculo de métricas

# %% [markdown]
# #### TAMAÑO

# %%
print('n =', len(g.vs))
print('m =', len(g.es))
print('c =', round(igraph.mean(g.degree()),2))
print('densidad =', round(g.density(), 5))
print('diámetro =', g.diameter())
print('l (longitud del camino medio) =', round(g.average_path_length(),2))
# Out:
# n = 3214
# m = 18859
# c = 11.74
# densidad = 0.00365
# diámetro = 12
# l (longitud del camino medio) = 3.96

# %% [markdown]
# ##### Rutas más largas

# %%
distances = g.shortest_paths()
da = np.array(distances).flatten()
sort = np.sort(da[da != float('inf')])[::-1]

# %%
plt.hist(sort, bins = 12)
plt.title('Histograma de les rutes del graf', fontsize=15)
plt.xlabel('Distància de la ruta')
plt.ylabel('Nombre de rutes')
plt.show()

# %% [markdown]
# Ejemplo de ruta de longitud 12:

# %%
maximum = 0
max_index_src = 0
max_index_dst = 0
for i, src in enumerate(distances):
    arr = np.array(src)
    max_value = np.max(arr[arr != float('inf')])
    
    if max_value > maximum:
        max_index_dst = src.index(max_value)
        max_index_src = i
        maximum = max_value

shortest_path = g.get_shortest_paths(v=max_index_src, to=max_index_dst)[0]
shortest_path_ids = [g.vs['name'][i] for i in shortest_path]
shortest_path_edges = [(shortest_path_ids[i], shortest_path_ids[i+1]) for i in range(len(shortest_path_ids)-1)]
print(shortest_path_ids)
info_aeropuerto_vertice(airports, g, shortest_path)
# Out:
# ['5535', '5504', '5506', '6727', '62', '146', '193', '143', '91', '5490', '5543', '5482', '5522']
#         Id                                               Name  \
# 61      62                          La Grande Rivière Airport
# 90      91                                   Moosonee Airport
# 141    143                            Timmins/Victor M. Power
# 144    146  Montreal / Pierre Elliott Trudeau Internationa...
# 191    193            Lester B. Pearson International Airport
# 4188  5482                               Attawapiskat Airport
# 4196  5490                                Fort Albany Airport
# 4210  5504                                   Ivujivik Airport
# 4212  5506                                   Akulivik Airport
# 4228  5522                                  Peawanuck Airport
# 4241  5535                                    Salluit Airport
# 4249  5543                                Kashechewan Airport
# 5112  6727                                 Puvirnituq Airport
#
#                    City Country IATA  ICAO   Latitude  Longitude  Altitude  \
# 61    La Grande Riviere  Canada  YGL  CYGL  53.625301 -77.704201       639
# 90             Moosonee  Canada  YMO  CYMO  51.291100 -80.607803        30
# 141             Timmins  Canada  YTS  CYTS  48.569698 -81.376701       967
# 144            Montreal  Canada  YUL  CYUL  45.470600 -73.740799       118
# 191             Toronto  Canada  YYZ  CYYZ  43.677200 -79.630600       569
# 4188       Attawapiskat  Canada  YAT  CYAT  52.927502 -82.431900        31
# 4196        Fort Albany  Canada  YFA  CYFA  52.201401 -81.696899        48
# 4210           Ivujivik  Canada  YIK  CYIK  62.417301 -77.925301       126
# 4212           Akulivik  Canada  AKV  CYKO  60.818600 -78.148598        75
# 4228          Peawanuck  Canada  YPO  CYPO  54.988098 -85.443298       173
# 4241            Salluit  Canada  YZG  CYZG  62.179401 -75.667198       743
# 4249        Kashechewan  Canada  ZKE  CZKE  52.282501 -81.677803        35
# 5112         Puvirnituq  Canada  YPX  CYPX  60.050598 -77.286903        74
#
#       Timezone DST Tz database time zone     Type       Source
# 61        -5.0   A       America/Toronto  airport  OurAirports
# 90        -5.0   A       America/Toronto  airport  OurAirports
# 141       -5.0   A       America/Toronto  airport  OurAirports
# 144       -5.0   A       America/Toronto  airport  OurAirports
# 191       -5.0   A       America/Toronto  airport  OurAirports
# 4188      -5.0   A       America/Toronto  airport  OurAirports
# 4196      -5.0   A       America/Toronto  airport  OurAirports
# 4210      -5.0   A       America/Toronto  airport  OurAirports
# 4212      -5.0   A       America/Toronto  airport  OurAirports
# 4228      -5.0   A       America/Toronto  airport  OurAirports
# 4241      -5.0   A       America/Toronto  airport  OurAirports
# 4249      -5.0   A       America/Toronto  airport  OurAirports
# 5112      -5.0   A       America/Toronto  airport  OurAirports

# %% [markdown]
# Cas de ruta més llarga a Canadà (12):

# %%
# GRAF AMB ARESTES DE RUTA MÉS LLARGA EN VERMELL
g = igraph.Graph()

for i, row in dfs.iterrows():
    if row.Src_Country == 'Canada' and row.Dst_Country == 'Canada':
        if 'name' not in g.vs.attribute_names():
            g.add_vertex(
                name=str(row.Src_A_ID),
                color= 'red' if ((str(row.Src_A_ID), str(row.Dst_A_ID)) in shortest_path_edges) or ((str(row.Dst_A_ID), str(row.Src_A_ID)) in shortest_path_edges) else 'black')
            g.add_vertex(
                name=str(row.Dst_A_ID),
                color= 'red' if ((str(row.Src_A_ID), str(row.Dst_A_ID)) in shortest_path_edges) or ((str(row.Dst_A_ID), str(row.Src_A_ID)) in shortest_path_edges) else 'black')
        else:
            if str(row.Src_A_ID) not in g.vs['name']:
                g.add_vertex(
                    name=str(row.Src_A_ID),
                    color= 'red' if ((str(row.Src_A_ID), str(row.Dst_A_ID)) in shortest_path_edges) or ((str(row.Dst_A_ID), str(row.Src_A_ID)) in shortest_path_edges) else 'black')
            if str(row.Dst_A_ID) not in g.vs['name']:
                g.add_vertex(
                    name=str(row.Dst_A_ID),
                    color= 'red' if ((str(row.Src_A_ID), str(row.Dst_A_ID)) in shortest_path_edges) or ((str(row.Dst_A_ID), str(row.Src_A_ID)) in shortest_path_edges) else 'black')
        if not g.are_connected(str(row.Src_A_ID), str(row.Dst_A_ID)):
            g.add_edge(
                str(row.Src_A_ID), str(row.Dst_A_ID), 
                rutas=[i], 
                color= 'red' if ((str(row.Src_A_ID), str(row.Dst_A_ID)) in shortest_path_edges) or ((str(row.Dst_A_ID), str(row.Src_A_ID)) in shortest_path_edges) else 'black')
        
print(g.summary())

random.seed(12345)
igraph.plot(g, bbox=(600, 600), vertex_size=10)
# Out:
# IGRAPH UN-- 205 430 --
# + attr: color (v), name (v), color (e), rutas (e)

# %%
# GRAF SENSE CANADÀ NI ESTATS UNITS
# g = igraph.Graph()

# for i, row in dfs.iterrows():
#     if row.Src_Country != 'Canada' and row.Dst_Country != 'Canada' and row.Src_Country != 'United States' and row.Dst_Country != 'United States':
#         if 'name' not in g.vs.attribute_names():
#             g.add_vertex(name=str(row.Src_A_ID), color=dict_colors[row.Src_Country], label=str(row.Src_A_ID))
#             g.add_vertex(name=str(row.Dst_A_ID), color=dict_colors[row.Dst_Country], label=str(row.Dst_A_ID))
#         else:
#             if str(row.Src_A_ID) not in g.vs['name']:
#                 g.add_vertex(name=str(row.Src_A_ID), color=dict_colors[row.Src_Country], label=str(row.Src_A_ID))
#             if str(row.Dst_A_ID) not in g.vs['name']:
#                 g.add_vertex(name=str(row.Dst_A_ID), color=dict_colors[row.Dst_Country], label=str(row.Dst_A_ID))
#         if not g.are_connected(str(row.Src_A_ID), str(row.Dst_A_ID)):
#             g.add_edge(str(row.Src_A_ID), str(row.Dst_A_ID), rutas=[i])
#         else:
#             g.es['rutas'][g.get_eid(str(row.Src_A_ID), str(row.Dst_A_ID))].append(i)
        
# print(g.summary())

# out = igraph.plot(g, **visual_style)
# out.save('graf_sense_Canada_EEUU.png')
# Out:
# IGRAPH UN-- 2452 14378 --
# + attr: color (v), label (v), name (v), rutas (e)

# %% [markdown]
# #### COMPONENTES

# %%
comps = sorted(g.clusters(), key=len, reverse=True)
print('nº components =', len(g.clusters()))
print('Mida de les components =', [len(i) for i in comps])
print('S =', round(len(comps[0]))/len(g.vs), 5)
# Out:
# nº components = 7
# Mida de les components = [3188, 10, 4, 4, 4, 2, 2]
# S = 0.9919103920348475 5

# %% [markdown]
# Llista d'aeroports de cada component:

# %%
info_aeropuerto_vertice(airports, g, comps[1])
# Out:
#         Id                     Name          City        Country IATA  ICAO  \
# 1928  1998             Koné Airport          Kone  New Caledonia  KNQ  NWWD
# 1929  1999           Koumac Airport        Koumac  New Caledonia  KOC  NWWK
# 1930  2000            Lifou Airport         Lifou  New Caledonia  LIF  NWWL
# 1931  2001   Nouméa Magenta Airport        Noumea  New Caledonia  GEA  NWWM
# 1932  2002             Maré Airport          Mare  New Caledonia  MEE  NWWR
# 1933  2003            Touho Airport         Touho  New Caledonia  TOU  NWWU
# 1934  2004            Ouvéa Airport         Ouvea  New Caledonia  UVE  NWWV
# 4586  5919             Tiga Airport          Tiga  New Caledonia  TGJ  NWWA
# 4587  5920  Île Art - Waala Airport         Waala  New Caledonia  BMY  NWWC
# 4588  5921     Île des Pins Airport  Île des Pins  New Caledonia  ILP  NWWE
#
#        Latitude   Longitude  Altitude  Timezone DST Tz database time zone  \
# 1928 -21.054300  164.837006        23      11.0   U        Pacific/Noumea
# 1929 -20.546301  164.255997        42      11.0   U        Pacific/Noumea
# 1930 -20.774799  167.240005        92      11.0   U        Pacific/Noumea
# 1931 -22.258301  166.473007        10      11.0   U        Pacific/Noumea
# 1932 -21.481701  168.037994       141      11.0   U        Pacific/Noumea
# 1933 -20.790001  165.259003        10      11.0   U        Pacific/Noumea
# 1934 -20.640600  166.572998        23      11.0   U        Pacific/Noumea
# 4586 -21.096100  167.804001       128      11.0   U        Pacific/Noumea
# 4587 -19.720600  163.660995       306      11.0   U        Pacific/Noumea
# 4588 -22.588900  167.455994       315      11.0   U        Pacific/Noumea
#
#          Type       Source
# 1928  airport  OurAirports
# 1929  airport  OurAirports
# 1930  airport  OurAirports
# 1931  airport  OurAirports
# 1932  airport  OurAirports
# 1933  airport  OurAirports
# 1934  airport  OurAirports
# 4586  airport  OurAirports
# 4587  airport  OurAirports
# 4588  airport  OurAirports

# %%
info_aeropuerto_vertice(airports, g, comps[2])
# Out:
#         Id                   Name      City  Country IATA  ICAO   Latitude  \
# 4344  5642       Ondangwa Airport  Ondangwa  Namibia  OND  FYOA -17.878201
# 4347  5645           Eros Airport  Windhoek  Namibia  ERS  FYWE -22.612200
# 5162  6779  Katima Mulilo Airport    Mpacha  Namibia  MPA  FYKM -17.634399
# 5719  7634          Rundu Airport     Rundu  Namibia  NDU  FYRU -17.956499
#
#       Longitude  Altitude  Timezone DST Tz database time zone     Type  \
# 4344  15.952600      3599       1.0   S       Africa/Windhoek  airport
# 4347  17.080400      5575       1.0   S       Africa/Windhoek  airport
# 5162  24.176701      3144       1.0   S       Africa/Windhoek  airport
# 5719  19.719400      3627       1.0   S       Africa/Windhoek  airport
#
#            Source
# 4344  OurAirports
# 4347  OurAirports
# 5162  OurAirports
# 5719  OurAirports

# %%
info_aeropuerto_vertice(airports, g, comps[3])
# Out:
#         Id                  Name      City        Country IATA  ICAO  \
# 3660  3860      Unalaska Airport  Unalaska  United States  DUT  PADU
# 4769  6134  Akutan Seaplane Base    Akutan  United States  KQA   KQA
# 5431  7195          Atka Airport      Atka  United States  AKB  PAAK
# 5432  7196  Nikolski Air Station  Nikolski  United States  IKO  PAKO
#
#        Latitude   Longitude  Altitude  Timezone DST Tz database time zone  \
# 3660  53.900101 -166.544006        22      -9.0   A     America/Anchorage
# 4769  54.133770 -165.778896         0      -9.0   A     America/Anchorage
# 5431  52.220299 -174.205994        57     -10.0   A          America/Adak
# 5432  52.941601 -168.848999        77      -9.0   A     America/Anchorage
#
#          Type       Source
# 3660  airport  OurAirports
# 4769  airport  OurAirports
# 5431  airport  OurAirports
# 5432  airport  OurAirports

# %%
info_aeropuerto_vertice(airports, g, comps[4])
# Out:
#         Id                                            Name           City  \
# 3526  3726  Boeing Field King County International Airport        Seattle
# 4423  5731       William R Fairchild International Airport   Port Angeles
# 5363  7082                           Friday Harbor Airport  Friday Harbor
# 5364  7083                            Orcas Island Airport      Eastsound
#
#             Country IATA  ICAO   Latitude   Longitude  Altitude  Timezone DST  \
# 3526  United States  BFI  KBFI  47.529999 -122.302002        21      -8.0   A
# 4423  United States  CLM  KCLM  48.120201 -123.500000       291      -8.0   A
# 5363  United States  FRD  KFHR  48.521999 -123.024002       113      -8.0   A
# 5364  United States  ESD  KORS  48.708199 -122.910004        31      -8.0   A
#
#      Tz database time zone     Type       Source
# 3526   America/Los_Angeles  airport  OurAirports
# 4423   America/Los_Angeles  airport  OurAirports
# 5363   America/Los_Angeles  airport  OurAirports
# 5364   America/Los_Angeles  airport  OurAirports

# %%
info_aeropuerto_vertice(airports, g, comps[5])
# Out:
#         Id                       Name              City    Country IATA  ICAO  \
# 4151  5439    Neerlerit Inaat Airport   Neerlerit Inaat  Greenland  CNP  BGCO
# 6008  8208  Ittoqqortoormiit Heliport  Ittoqqortoormiit  Greenland  OBY  BGSC
#
#        Latitude  Longitude  Altitude  Timezone DST Tz database time zone  \
# 4151  70.743103 -22.650499        45      -1.0   E  America/Scoresbysund
# 6008  70.488229 -21.971680       238      -1.0   U  America/Scoresbysund
#
#          Type       Source
# 4151  airport  OurAirports
# 6008  airport  OurAirports

# %%
info_aeropuerto_vertice(airports, g, comps[6])
# Out:
#         Id                               Name       City Country IATA  ICAO  \
# 3883  4106     Victoria Harbour Seaplane Base   Victoria  Canada  YWH  CYWH
# 4206  5500  Vancouver Harbour Water Aerodrome  Vancouver  Canada  CXH  CYHC
#
#        Latitude   Longitude  Altitude  Timezone DST Tz database time zone  \
# 3883  48.424986 -123.388867         0      -8.0   A     America/Vancouver
# 4206  49.294399 -123.111000         0      -8.0   A     America/Vancouver
#
#          Type       Source
# 3883  airport  OurAirports
# 4206  airport  OurAirports

# %% [markdown]
# #### ÍNDICES DE CENTRALIDAD

# %%
print('eigenvector =', round(igraph.mean(g.eigenvector_centrality()),5))
print('pagerank =', round(igraph.mean(g.pagerank()),5))

print('closeness =', round(igraph.mean(g.closeness()),5))
print('betweenness =', round(igraph.mean(g.betweenness()),5))
print('clustering =', round(g.transitivity_undirected(),5))
# Out:
# eigenvector = 0.0387
# pagerank = 0.00031
# closeness = 0.26339
# betweenness = 4676.29278
# clustering = 0.24972

# %% [markdown]
# ##### Eigenvector

# %%
eigenvector = g.eigenvector_centrality()
top10 = sorted(list(enumerate(eigenvector)), key=lambda tup: tup[1])[:-11:-1]
for i in range(len(top10)):
    top10[i] = (g.vs['name'][top10[i][0]], top10[i][1])
top10
# Out:
# [('580', 1.0),
#  ('340', 0.9910397956247187),
#  ('1382', 0.9497305572060977),
#  ('346', 0.8848422177290118),
#  ('1555', 0.8121283542287704),
#  ('507', 0.809534009912402),
#  ('1701', 0.769371416262263),
#  ('1218', 0.7635243816251865),
#  ('1678', 0.7506244618804356),
#  ('1229', 0.7326472845898895)]

# %%
top10_ids = [tup[0] for tup in top10]
info_aeropuerto_vertice(airports, g, top10_ids)
# Out:
#         Id                                     Name       City  \
# 336    340                Frankfurt am Main Airport  Frankfurt
# 342    346                           Munich Airport     Munich
# 502    507                  London Heathrow Airport     London
# 574    580               Amsterdam Airport Schiphol  Amsterdam
# 1186  1218          Barcelona International Airport  Barcelona
# 1196  1229     Adolfo Suárez Madrid–Barajas Airport     Madrid
# 1346  1382  Charles de Gaulle International Airport      Paris
# 1514  1555      Leonardo da Vinci–Fiumicino Airport       Rome
# 1633  1678                           Zürich Airport     Zurich
# 1655  1701            Atatürk International Airport   Istanbul
#
#              Country IATA  ICAO   Latitude  Longitude  Altitude  Timezone DST  \
# 336          Germany  FRA  EDDF  50.033333   8.570556       364       1.0   E
# 342          Germany  MUC  EDDM  48.353802  11.786100      1487       1.0   E
# 502   United Kingdom  LHR  EGLL  51.470600  -0.461941        83       0.0   E
# 574      Netherlands  AMS  EHAM  52.308601   4.763890       -11       1.0   E
# 1186           Spain  BCN  LEBL  41.297100   2.078460        12       1.0   E
# 1196           Spain  MAD  LEMD  40.471926  -3.562640      1998       1.0   E
# 1346          France  CDG  LFPG  49.012798   2.550000       392       1.0   E
# 1514           Italy  FCO  LIRF  41.800278  12.238889        13       1.0   E
# 1633     Switzerland  ZRH  LSZH  47.464699   8.549170      1416       1.0   E
# 1655          Turkey  ISL  LTBA  40.976898  28.814600       163       3.0   E
#
#      Tz database time zone     Type       Source
# 336          Europe/Berlin  airport  OurAirports
# 342          Europe/Berlin  airport  OurAirports
# 502          Europe/London  airport  OurAirports
# 574       Europe/Amsterdam  airport  OurAirports
# 1186         Europe/Madrid  airport  OurAirports
# 1196         Europe/Madrid  airport  OurAirports
# 1346          Europe/Paris  airport  OurAirports
# 1514           Europe/Rome  airport  OurAirports
# 1633         Europe/Zurich  airport  OurAirports
# 1655       Europe/Istanbul  airport  OurAirports

# %% [markdown]
# ##### Pagerank

# %%
pagerank = g.pagerank()
top10 = sorted(list(enumerate(pagerank)), key=lambda tup: tup[1])[:-11:-1]
for i in range(len(top10)):
    top10[i] = (g.vs['name'][top10[i][0]], top10[i][1])
top10
# Out:
# [('3682', 0.004825883012346701),
#  ('3830', 0.004496999734166884),
#  ('1701', 0.004482661649597792),
#  ('3670', 0.004429577419402398),
#  ('3751', 0.00438780292705088),
#  ('1382', 0.004171008337545877),
#  ('4029', 0.004137341608919111),
#  ('580', 0.004105507355435134),
#  ('340', 0.004046319438946044),
#  ('3364', 0.003929902916080832)]

# %%
top10_ids = [tup[0] for tup in top10]
info_aeropuerto_vertice(airports, g, top10_ids)
# Out:
#         Id                                              Name  \
# 336    340                         Frankfurt am Main Airport
# 574    580                        Amsterdam Airport Schiphol
# 1346  1382           Charles de Gaulle International Airport
# 1655  1701                     Atatürk International Airport
# 3170  3364             Beijing Capital International Airport
# 3470  3670           Dallas Fort Worth International Airport
# 3482  3682  Hartsfield Jackson Atlanta International Airport
# 3551  3751                      Denver International Airport
# 3630  3830              Chicago O'Hare International Airport
# 3815  4029                  Domodedovo International Airport
#
#                    City        Country IATA  ICAO   Latitude   Longitude  \
# 336           Frankfurt        Germany  FRA  EDDF  50.033333    8.570556
# 574           Amsterdam    Netherlands  AMS  EHAM  52.308601    4.763890
# 1346              Paris         France  CDG  LFPG  49.012798    2.550000
# 1655           Istanbul         Turkey  ISL  LTBA  40.976898   28.814600
# 3170            Beijing          China  PEK  ZBAA  40.080101  116.584999
# 3470  Dallas-Fort Worth  United States  DFW  KDFW  32.896801  -97.038002
# 3482            Atlanta  United States  ATL  KATL  33.636700  -84.428101
# 3551             Denver  United States  DEN  KDEN  39.861698 -104.672997
# 3630            Chicago  United States  ORD  KORD  41.978600  -87.904800
# 3815             Moscow         Russia  DME  UUDD  55.408798   37.906300
#
#       Altitude  Timezone DST Tz database time zone     Type       Source
# 336        364       1.0   E         Europe/Berlin  airport  OurAirports
# 574        -11       1.0   E      Europe/Amsterdam  airport  OurAirports
# 1346       392       1.0   E          Europe/Paris  airport  OurAirports
# 1655       163       3.0   E       Europe/Istanbul  airport  OurAirports
# 3170       116       8.0   U         Asia/Shanghai  airport  OurAirports
# 3470       607      -6.0   A       America/Chicago  airport  OurAirports
# 3482      1026      -5.0   A      America/New_York  airport  OurAirports
# 3551      5431      -7.0   A        America/Denver  airport  OurAirports
# 3630       672      -6.0   A       America/Chicago  airport  OurAirports
# 3815       588       3.0   N         Europe/Moscow  airport  OurAirports

# %% [markdown]
# ##### Closeness

# %%
closeness = g.closeness()
top10 = sorted(list(enumerate(closeness)), key=lambda tup: tup[1])[:-11:-1]
for i in range(len(top10)):
    top10[i] = (g.vs['name'][top10[i][0]], top10[i][1])
top10
# Out:
# [('2001', 1.0),
#  ('3726', 1.0),
#  ('4106', 1.0),
#  ('5500', 1.0),
#  ('3860', 1.0),
#  ('8208', 1.0),
#  ('5439', 1.0),
#  ('5645', 1.0),
#  ('7082', 0.75),
#  ('7083', 0.75)]

# %%
top10_ids = [tup[0] for tup in top10]
info_aeropuerto_vertice(airports, g, top10_ids)
# Out:
#         Id                                            Name              City  \
# 1931  2001                          Nouméa Magenta Airport            Noumea
# 3526  3726  Boeing Field King County International Airport           Seattle
# 3660  3860                                Unalaska Airport          Unalaska
# 3883  4106                  Victoria Harbour Seaplane Base          Victoria
# 4151  5439                         Neerlerit Inaat Airport   Neerlerit Inaat
# 4206  5500               Vancouver Harbour Water Aerodrome         Vancouver
# 4347  5645                                    Eros Airport          Windhoek
# 5363  7082                           Friday Harbor Airport     Friday Harbor
# 5364  7083                            Orcas Island Airport         Eastsound
# 6008  8208                       Ittoqqortoormiit Heliport  Ittoqqortoormiit
#
#             Country IATA  ICAO   Latitude   Longitude  Altitude  Timezone DST  \
# 1931  New Caledonia  GEA  NWWM -22.258301  166.473007        10      11.0   U
# 3526  United States  BFI  KBFI  47.529999 -122.302002        21      -8.0   A
# 3660  United States  DUT  PADU  53.900101 -166.544006        22      -9.0   A
# 3883         Canada  YWH  CYWH  48.424986 -123.388867         0      -8.0   A
# 4151      Greenland  CNP  BGCO  70.743103  -22.650499        45      -1.0   E
# 4206         Canada  CXH  CYHC  49.294399 -123.111000         0      -8.0   A
# 4347        Namibia  ERS  FYWE -22.612200   17.080400      5575       1.0   S
# 5363  United States  FRD  KFHR  48.521999 -123.024002       113      -8.0   A
# 5364  United States  ESD  KORS  48.708199 -122.910004        31      -8.0   A
# 6008      Greenland  OBY  BGSC  70.488229  -21.971680       238      -1.0   U
#
#      Tz database time zone     Type       Source
# 1931        Pacific/Noumea  airport  OurAirports
# 3526   America/Los_Angeles  airport  OurAirports
# 3660     America/Anchorage  airport  OurAirports
# 3883     America/Vancouver  airport  OurAirports
# 4151  America/Scoresbysund  airport  OurAirports
# 4206     America/Vancouver  airport  OurAirports
# 4347       Africa/Windhoek  airport  OurAirports
# 5363   America/Los_Angeles  airport  OurAirports
# 5364   America/Los_Angeles  airport  OurAirports
# 6008  America/Scoresbysund  airport  OurAirports

# %% [markdown]
# ##### Betweenness

# %%
betweenness = g.betweenness()
top10 = sorted(list(enumerate(betweenness)), key=lambda tup: tup[1])[:-11:-1]
for i in range(len(top10)):
    top10[i] = (g.vs['name'][top10[i][0]], top10[i][1])
top10
# Out:
# [('1382', 327988.10917691817),
#  ('3484', 312198.1080670245),
#  ('3774', 301486.4351182183),
#  ('2188', 285897.28954097896),
#  ('340', 270552.4070156179),
#  ('580', 263489.1115801093),
#  ('3364', 256910.51591503594),
#  ('3830', 240371.19893043122),
#  ('193', 228825.55597963123),
#  ('1701', 218931.24591473403)]

# %%
top10_ids = [tup[0] for tup in top10]
info_aeropuerto_vertice(airports, g, top10_ids)
# Out:
#         Id                                         Name         City  \
# 191    193      Lester B. Pearson International Airport      Toronto
# 336    340                    Frankfurt am Main Airport    Frankfurt
# 574    580                   Amsterdam Airport Schiphol    Amsterdam
# 1346  1382      Charles de Gaulle International Airport        Paris
# 1655  1701                Atatürk International Airport     Istanbul
# 2100  2188                  Dubai International Airport        Dubai
# 3170  3364        Beijing Capital International Airport      Beijing
# 3285  3484            Los Angeles International Airport  Los Angeles
# 3574  3774  Ted Stevens Anchorage International Airport    Anchorage
# 3630  3830         Chicago O'Hare International Airport      Chicago
#
#                    Country IATA  ICAO   Latitude   Longitude  Altitude  \
# 191                 Canada  YYZ  CYYZ  43.677200  -79.630600       569
# 336                Germany  FRA  EDDF  50.033333    8.570556       364
# 574            Netherlands  AMS  EHAM  52.308601    4.763890       -11
# 1346                France  CDG  LFPG  49.012798    2.550000       392
# 1655                Turkey  ISL  LTBA  40.976898   28.814600       163
# 2100  United Arab Emirates  DXB  OMDB  25.252800   55.364399        62
# 3170                 China  PEK  ZBAA  40.080101  116.584999       116
# 3285         United States  LAX  KLAX  33.942501 -118.407997       125
# 3574         United States  ANC  PANC  61.174400 -149.996002       152
# 3630         United States  ORD  KORD  41.978600  -87.904800       672
#
#       Timezone DST Tz database time zone     Type       Source
# 191       -5.0   A       America/Toronto  airport  OurAirports
# 336        1.0   E         Europe/Berlin  airport  OurAirports
# 574        1.0   E      Europe/Amsterdam  airport  OurAirports
# 1346       1.0   E          Europe/Paris  airport  OurAirports
# 1655       3.0   E       Europe/Istanbul  airport  OurAirports
# 2100       4.0   U            Asia/Dubai  airport  OurAirports
# 3170       8.0   U         Asia/Shanghai  airport  OurAirports
# 3285      -8.0   A   America/Los_Angeles  airport  OurAirports
# 3574      -9.0   A     America/Anchorage  airport  OurAirports
# 3630      -6.0   A       America/Chicago  airport  OurAirports

# %% [markdown]
# ##### Clustering

# %%
print('clustering =', round(g.transitivity_undirected(),5))
# Out:
# clustering = 0.24972

# %% [markdown]
# ##### Comparativa de índices

# %%
centrality = pd.DataFrame(list(zip(eigenvector, pagerank, closeness, betweenness)), columns =['eigenvector', 'pagerank', 'closeness', 'betweenness'])

corrMatrix = centrality.corr()
sn.heatmap(corrMatrix, annot=True, cmap="Blues")
plt.show()

# %% [markdown]
# ##### Homofília

# %%
# g.assortativity_nominal(g.vs.indices, g.vs['color'])
g.assortativity_degree(g.vs.indices)
# Out:
# -0.016633481283398168

# %% [markdown]
# #### APROXIMACIÓN A POWER LAW

# %%
plt.rcParams['figure.figsize'] = [20, 5]
plt.rcParams['font.size'] = 16

f, axarr = plt.subplots(1,2)

axarr[0].title.set_text('Histograma')
axarr[0].hist(g.degree(), bins=150)

axarr[1].title.set_text('Histograma en escala logarítmica')
axarr[1].hist(g.degree(), 150)
axarr[1].set_xscale('log')
axarr[1].set_yscale('log')

# %%
print('PowerLaw Fit: ' + str(igraph.power_law_fit(g.degree())))
# Out:
# PowerLaw Fit: Fitted power-law distribution on discrete data
#
# Exponent (alpha)  = 1.713560
# Cutoff (xmin)     = 2.000000
#
# Log-likelihood    = -7967.485102
#
# H0: data was drawn from the fitted distribution
#
# KS test statistic = 0.037779
# p-value           = 0.001610
#
# H0 rejected at significance level 0.05

# %%
# import networkx as nx
# G = nx.Graph(g.get_edgelist())

# %%
# k_components = nx.k_components(G)
